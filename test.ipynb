# %% [markdown]
# <a href="https://colab.research.google.com/github/2pterons/twigfarm_test/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# %cd /content/drive/MyDrive/Colab Notebooks/트위그팜/자연스러운 한국어/data/

_data = ['200_train_data2.txt', '200_train_data2.txt', '200_train_data2.txt']
_save = ['new_train.txt', 'new_test.txt', 'new_val.txt']
_header = ['id', 'document', 'label']

save_data = pd.DataFrame()

cnt = 1
cnt2 = 0
for i in _data:
    var = pd.read_csv(f'/content/drive/MyDrive/Colab Notebooks/트위그팜/자연스러운 한국어/data/{i}', sep='\t', header=None)
    for j in range(1, len(var.columns)):
      overlap = []
      for k in var[j]:
        line = k.strip().split('\t')
        print(k)
        #print(line)
        if line not in overlap:
          overlap.append(line)
          save_data[_header[cnt]] = line
          save_data[_header[cnt]].to_csv(str(_save[cnt2]), mode='a', header=None)
          #line[_header[cnt]].to_csv(str(_save[cnt2]), mode='a', header=None)
          #pd.to_csvline
      cnt += 1
    cnt2 += 1 

save_data.columns = ['id', 'document', 'label']
# Out:
# /content/drive/MyDrive/Colab Notebooks/트위그팜/자연스러운 한국어/data
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 표정은 다르지만 혼자 잘 수 있는 것은 마음이 많이 상했을 때뿐이다.
# 나중에 두 분이 매달 10~20만 원만 받을 수 있어도 좋죠.
# 얼마 전까지만 해도 양귀비꽃이 붉게 물든 곳이었다.
# 내가 나림을 봤을 때 그녀는 자장면을 마시고 있었다.
# 현재 기사는 이 브런치 책에 속해 있습니다.
# 공부를 방해하는 습관을 하나씩 고쳐나가야 성적 향상을 기대할 수 있습니다.
# 그의 가족도 아니었고 경제적 능력도 없었습니다.
# 심지어 제대로 인증샷을 찍으면 줄까지 서서 기다려야
# 봄이 되자 텅 빈 화단에 숨어 있던 야생화가 먼저 땅에 파랗게 물든 잎사귀를 드러냈다.
# 일화를 소개하자면 맥주 회사의 위생을 의심하는 기자가 있었다.
# 밥의 양도 넉넉해서 식탁에 앉아 첫 곡식을 먹듯이.
# 엄마가 평소에 잘 안먹던 음식들.
# 들꽃은이유 없이 사람들에게 밟혀 사라지기도 쉽다.
# 나는 골파 씨앗을 얻어 정원 가장자리에 심었습니다.
# 그러나 그 결정적인 사람은 어디에도 보이지 않았다.
# 내가 대학에 다닐 무렵을 떠올려보니 새삼 알바 르네상스기였단 생각을 했다.
# 전직 초등학교 교사 2명은 지금은 작은 농사일을 하며 하루를 보낸다고 한다.
# 나는 성공이 필요 없다고 말했지만 나는 그렇지 않았다
# ...
